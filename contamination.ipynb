# %% [markdown]
# <a href="https://colab.research.google.com/github/Gylla/Proyectos_Analisis-de-datos/blob/main/contamination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importación de la Data

# %%
# !wget -O final_dataset.csv https://raw.githubusercontent.com/Gylla/Proyectos_Analisis-de-datos/refs/heads/main/Contamination/Data/final_dataset.csv
df = pd.read_csv('final_dataset.csv', sep=",")
# Out:
# --2025-08-02 21:16:05--  https://raw.githubusercontent.com/Gylla/Proyectos_Analisis-de-datos/refs/heads/main/Contamination/Data/final_dataset.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76906 (75K) [text/plain]
# Saving to: ‘final_dataset.csv’
#
# final_dataset.csv   100%[===================>]  75.10K  --.-KB/s    in 0.02s
#
# 2025-08-02 21:16:05 (3.51 MB/s) - ‘final_dataset.csv’ saved [76906/76906]

# %%
df.head()
# Out:
#    Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0     1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1     2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2     3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3     4      1  2021               0     1   89.55  132.08  153.98  10.42
# 4     5      1  2021               0     2   54.06   55.54  122.66   9.70
#
#      CO  Ozone  AQI
# 0  2.77  43.19  462
# 1  2.60  16.43  482
# 2  1.40  44.29  263
# 3  1.01  49.19  207
# 4  0.64  48.88  149

# %% [markdown]
# #  ETL (Extracción, Transformación y Carga)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            1461 non-null   int64
#  1   Month           1461 non-null   int64
#  2   Year            1461 non-null   int64
#  3   Holidays_Count  1461 non-null   int64
#  4   Days            1461 non-null   int64
#  5   PM2.5           1461 non-null   float64
#  6   PM10            1461 non-null   float64
#  7   NO2             1461 non-null   float64
#  8   SO2             1461 non-null   float64
#  9   CO              1461 non-null   float64
#  10  Ozone           1461 non-null   float64
#  11  AQI             1461 non-null   int64
# dtypes: float64(6), int64(6)
# memory usage: 137.1 KB

# %%
df.describe()
# Out:
#               Date        Month         Year  Holidays_Count         Days  \
# count  1461.000000  1461.000000  1461.000000     1461.000000  1461.000000
# mean     15.729637     6.522930  2022.501027        0.189596     4.000684
# std       8.803105     3.449884     1.118723        0.392116     2.001883
# min       1.000000     1.000000  2021.000000        0.000000     1.000000
# 25%       8.000000     4.000000  2022.000000        0.000000     2.000000
# 50%      16.000000     7.000000  2023.000000        0.000000     4.000000
# 75%      23.000000    10.000000  2024.000000        0.000000     6.000000
# max      31.000000    12.000000  2024.000000        1.000000     7.000000
#
#              PM2.5         PM10          NO2          SO2           CO  \
# count  1461.000000  1461.000000  1461.000000  1461.000000  1461.000000
# mean     90.774538   218.219261    37.184921    20.104921     1.025832
# std      71.650579   129.297734    35.225327    16.543659     0.608305
# ...

# %%
# Crear una lista de tuplas con los resultados
results = []
for col in df.columns:
    pct_missing = np.mean(df[col].isnull()) * 100
    results.append((col, round(pct_missing, 2)))

# Convertir a DataFrame para mejor formato
results_df = pd.DataFrame(results, columns=['Columna', '% Faltante'])

# Imprimir como tabla Markdown
print(results_df.to_markdown(index=False, tablefmt="github", stralign="left", numalign="right"))
# Out:
# | Columna        |   % Faltante |
# |----------------|--------------|
# | Date           |            0 |
# | Month          |            0 |
# | Year           |            0 |
# | Holidays_Count |            0 |
# | Days           |            0 |
# | PM2.5          |            0 |
# | PM10           |            0 |
# | NO2            |            0 |
# | SO2            |            0 |
# | CO             |            0 |
# | Ozone          |            0 |
# | AQI            |            0 |

# %%
df.Days.unique()
# Out:
# array(['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuseday', 'Wednesday',
#        'Thursday'], dtype=object)

# %%
mapeo_cursos = {
    1: 'Monday',
    2: 'Tuseday',
    3: 'Wednesday',
    4: 'Thursday',
    5: 'Friday',
    6: 'Saturday',
    7: 'Sunday'
}

# %%
 df['Days'] = df['Days'].replace(mapeo_cursos)

# %%
df.head()
# Out:
#    Date  Month  Year  Holidays_Count      Days   PM2.5    PM10     NO2    SO2  \
# 0     1      1  2021               0    Friday  408.80  442.42  160.61  12.95
# 1     2      1  2021               0  Saturday  404.04  561.95   52.85   5.18
# 2     3      1  2021               1    Sunday  225.07  239.04  170.95  10.93
# 3     4      1  2021               0    Monday   89.55  132.08  153.98  10.42
# 4     5      1  2021               0   Tuseday   54.06   55.54  122.66   9.70
#
#      CO  Ozone  AQI
# 0  2.77  43.19  462
# 1  2.60  16.43  482
# 2  1.40  44.29  263
# 3  1.01  49.19  207
# 4  0.64  48.88  149
